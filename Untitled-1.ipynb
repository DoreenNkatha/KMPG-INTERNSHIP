# %%
import pandas as pd
import numpy as np

# %%
file = r'C:\Users\Doreen\Desktop\transactions kmpg.xlsx'
import chardet
with open (file,'rb') as rawdata:
     result= chardet.detect(rawdata.read(100000))

result
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
#Importing DataSet
Transactions = pd.read_csv(r'C:\Users\Doreen\Desktop\transactions kmpg.csv')
Transactions.columns = Transactions.iloc[0]
Transactions = Transactions[1:]
pd.set_option('display.max_columns', None)
Transactions.head()
# Out:
# c:\Users\Doreen\anaconda3\New folder\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,1,2,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0 transaction_id product_id customer_id transaction_date online_order  \
# 1              1          2        2950        2/25/2017        FALSE
# 2              2          3        3120        5/21/2017         TRUE
# 3              3         37         402       10/16/2017        FALSE
# 4              4         88        3135        8/31/2017        FALSE
# 5              5         78         787        10/1/2017         TRUE
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# ...

# %%
Transactions = pd.DataFrame(Transactions, columns =['transaction_id', 'product_id','customer_id','transaction_date', 'online_order', 'order_status','brand', 'product_line', 'product_class', 'product_size'])

Transactions.head()
# Out:
#   transaction_id product_id customer_id transaction_date online_order  \
# 1              1          2        2950        2/25/2017        FALSE
# 2              2          3        3120        5/21/2017         TRUE
# 3              3         37         402       10/16/2017        FALSE
# 4              4         88        3135        8/31/2017        FALSE
# 5              5         78         787        10/1/2017         TRUE
#
#   order_status           brand product_line product_class product_size
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large

# %%
Transactions.info()
Transactions.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 1 to 20000
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    20000 non-null  object
#  1   product_id        20000 non-null  object
#  2   customer_id       20000 non-null  object
#  3   transaction_date  20000 non-null  object
#  4   online_order      19640 non-null  object
#  5   order_status      20000 non-null  object
#  6   brand             19803 non-null  object
#  7   product_line      19803 non-null  object
#  8   product_class     19803 non-null  object
#  9   product_size      19803 non-null  object
# dtypes: object(10)
# memory usage: 1.5+ MB
#        transaction_id  product_id  customer_id transaction_date online_order  \
# count           20000       20000        20000            20000        19640
# unique          20000         202         5066              364            4
# ...

# %%
Transunique =pd.unique(Transactions[['online_order','order_status',	'brand','product_line',	'product_class','product_size']].values.ravel('K'))
Transunique
# Out:
# array(['FALSE', 'TRUE', nan, False, True, 'Approved', 'Cancelled',
#        'Solex', 'Trek Bicycles', 'OHM Cycles', 'Norco Bicycles',
#        'Giant Bicycles', 'WeareA2B', 'Standard', 'Road', 'Mountain',
#        'Touring', 'medium', 'low', 'high', 'large', 'small'], dtype=object)

# %%
Transactions.nunique()
Transactions['online_order'].unique()
# Out:
# array(['FALSE', 'TRUE', nan, False, True], dtype=object)

# %%
duplicate = Transactions[Transactions.duplicated()].sum()
duplicate
# Out:
# transaction_id      0.0
# product_id          0.0
# customer_id         0.0
# transaction_date    0.0
# online_order        0.0
# order_status        0.0
# brand               0.0
# product_line        0.0
# product_class       0.0
# product_size        0.0
# dtype: float64

# %% [markdown]
# Customer Demographic

# %%
Demographic = pd.read_csv(r'C:\Users\Doreen\Desktop\Customer Demographic.csv')
Demographic =pd.DataFrame(Demographic, columns = ['customer_id', 'first_name', 'last_name', 'gender','past_3_years_bike_related_purchases', 'DOB', 'job_title','job_industry_category', 'wealth_segment', 'deceased_indicator','owns_car','tenure'])
Demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
# 2                                   61  1954-01-20      Recruiting Manager
# 3                                   33  1961-10-03                     NaN
# 4                                   56  1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
Demographic.info()
Demographic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
Unique = Demographic.nunique()
Unique
Demographic['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
Demographic['gender'].replace(to_replace=['Female','Femal'], value= 'F', inplace = True)
Demographic['gender'].replace(to_replace =['Male'], value = 'M', inplace = True)
Demographic.nunique()
# Out:
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
Demographic['job_industry_category'].unique()
duplicates= Demographic[Demographic.duplicated()].sum()
duplicates
# Out:
# customer_id                            0.0
# first_name                             0.0
# last_name                              0.0
# gender                                 0.0
# past_3_years_bike_related_purchases    0.0
# DOB                                    0.0
# job_title                              0.0
# job_industry_category                  0.0
# wealth_segment                         0.0
# deceased_indicator                     0.0
# owns_car                               0.0
# tenure                                 0.0
# dtype: float64

# %% [markdown]
# Customer Address

# %%
Address = pd.read_csv(r'C:\Users\Doreen\Desktop\customer address.csv')
Address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                  10         NaN         NaN         NaN         NaN
# 1                  10         NaN         NaN         NaN         NaN
# 2                   9         NaN         NaN         NaN         NaN
# 3                   4         NaN         NaN         NaN         NaN
# 4                   9         NaN         NaN         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
Address = pd.DataFrame(Address, columns =['customer_id','address','postcode','state','country','property_valuation'])
Address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
Address.info()
Address.nunique()
Address['state'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)

# %%
duplicate = Address[Address.duplicated()].sum()
duplicate
# Out:
# customer_id           0.0
# address               0.0
# postcode              0.0
# state                 0.0
# country               0.0
# property_valuation    0.0
# dtype: float64

# %%
Address['state'].replace(to_replace= ('New South Wales','Victoria'), value= ('NSW','VIC'), inplace= True)
Address['state'].unique()
# Out:
# array(['NSW', 'QLD', 'VIC'], dtype=object)

# %%
del Address['country']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9516/931985053.py in <module>
# ----> 1 del Address['country']
#
# TypeError: 'NoneType' object does not support item deletion
